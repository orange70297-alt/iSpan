# %%
# f-string (又稱作 formatted string literals, version >= 3.6)
name = "Jarvis"
age = 18

msg = f"{name} is {age} years old."
print(msg)

print (f"{name} is {age} years old.")
# Out:
# Jarvis is 18 years old.
# Jarvis is 18 years old.

# %%
now = "2025-11-01 15:52"   #重要需要會
status = "INF0"
log = f"{now} [{status}-{msg}]"
print(log)
print(f"{now} [{status}-{msg}] ")
# Out:
# 2025-11-01 15:52 [INF0-Jarvis is 18 years old.]
# 2025-11-01 15:52 [INF0-Jarvis is 18 years old.]

# %%
# 靠左對齊、靠右對齊

name = "Jarvis"
age = 18
msg = f"name:[{name:<10},age:[{age:>10}]]"
print(msg)
# Out:
# name:[Jarvis    ,age:[        18]]

# %%
# 靠左對齊、靠右對齊，字數不足，補「ㄏ」
# (沒寫補什麼，預設空格)
name = "Jarvis"
age = 18
msg = f"name:[{name:ㄏ<10},age:[{age:ㄎ>10}]]"
print(msg)
# Out:
# name:[Jarvisㄏㄏㄏㄏ,age:[ㄎㄎㄎㄎㄎㄎㄎㄎ18]]

# %%
# 置中對齊

name = "Jarvis"
age = 18
msg = f"name:[{name:x^10},age:[{age:^6}]]"
print(msg)
# Out:
# name:[xxJarvisxx,age:[  18  ]]

# %%
# 指定文字長度上限 (只有文字，才在格式化字串中加入「.」來限定字串長度)

name = "Jarvis"
age = 18
msg = f"name:[{name:.3}]"
print(msg)
# Out:
# name:[Jar]

# %%
data = 3.145671475415
print(f"{data:.2f}")
# Out:
# 3.15
