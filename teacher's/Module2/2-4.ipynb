# %% [markdown]
# |取偶數 | 取奇數 |
# |:---|:---|
# |num%2==0 |num%2!=0 |

# %% [markdown]
# 算術運算子

# %%
print(5+4)
print(9%4)
print(9//4)
print(2**3)
# Out:
# 9
# 1
# 2
# 8

# %%
num = 10
if num % 2 == 0:
    print("num是偶數")
# Out:
# num是偶數

# %%
num1 = 9 + 4
num2 = 4
print(num1//num2)
print(num1%num2)
# Out:
# 3
# 1

# %% [markdown]
# 賦值運算子

# %%
a = 3
b = 4

b += a # 等同於 b = b + a
print(b)

a = 3
b = 4

b -= a # 等同於 b = b - a
print(b)
# Out:
# 7
# 1

# %%
a = 3
b = 4
print(b)
b *= a 
# 等同於 b = b * a
print(b)
# Out:
# 4
# 12

# %% [markdown]
# 比較運算子 (用 if 判斷)

# %%
print(5==5)
a = 10
b = 5
print(a==b)
print(a!=b)
# Out:
# True
# False
# True

# %%
a = 10
b = 5
if a != b:
    print("a不等於b")
# Out:
# a不等於b

# %%
score = 70
passing_score = 60

if score < passing_score:
    score += 10
    print("加分")

# Tab 縮排
# Shift+Tab 反縮排
print("學生的分數是:", score)
# Out:
# 學生的分數是: 70

# %% [markdown]
# 邏輯運算子 and / or / not

# %%
name = 'Alex'
age = 20

if name == 'Alex' and age == 20 and age >= 18:
    print('name: Alex; age: 18')
# Out:
# name: Alex; age: 18

# %%
if name == 'Alex' or age == 18:
    print('正確')
# Out:
# 正確

# %%
# JarvisLu
# aaa1029a1029@gmail.com

# %%
# not(False) 才會往下執行
if not(name=='Jarvis'):
    print('執行 not 語句')
# Out:
# 執行 not 語句

# %% [markdown]
# 成員運算子 in / not in

# %%
num_list = [1, 2, 3, 4]

if 1 in num_list:
    print('1 in list')

print(1 in num_list)
# Out:
# 1 in list
# True

# %%
if 5 not in num_list:
    print('5 not in list')
# Out:
# 5 not in list

# %% [markdown]
# 身分運算子 is / is not

# %%
x = 10
y = 10
print(x)
print(y)
print(id(x))
print(id(y))
# Out:
# 10
# 10
# 140720073188760
# 140720073188760

# %%
x = 10
y = 10
if x is y:
    print('x 和 y 參照到同一個記憶體位置')
# Out:
# x 和 y 參照到同一個記憶體位置

# %%
if x == y:
    print("x 等於 y")
# Out:
# x 等於 y

# %%
x = [1, 2, 3]
y = [1, 2, 3]
if x == y:
    print("x 等於 y")

print(id(x))
print(id(y))
if x is y:
    print("x 和 y 記憶體位置相同")
# Out:
# x 等於 y
# 2244569125760
# 2244568087680

# %%
parse_ok = True
if parse_ok is True:
    print("parse ok")
# Out:
# parse ok

# %% [markdown]
# 位元運算子

# %%
x = 1 # 0001
y = 3 # 0011
 
print(x&y) # 0001 # 1
print(x|y) # 0011 # 1+2
print(x^y) # 0010 # 2
# Out:
# 1
# 3
# 2
