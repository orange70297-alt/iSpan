# %%
# Shift + space 符號轉全型

# %%
# VS code 功能
# 複製單行程式碼 => Alt + Shift + ↑/↓

# %%
x = 20
print(x)
# Ctrl + Enter 執行 Cell
# 往上新增 cell -> A 
# 往下新增 cell -> B 
# 刪除 cell -> X 
# 跳出 cell -> Esc
# Out:
# 20

# %%
name = "Jarvis"
print(name)
# Out:
# Jarvis

# %%
class = 'A204'
# Out:
#   Cell In[8], line 1
#     class = 'A204'
#           ^
# SyntaxError: invalid syntax

# %%
MAX_SIZE = 100
print(MAX_SIZE)
# Out:
# 100
