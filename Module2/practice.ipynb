# %%
百貨公司周年慶 消費金額超過 2000 要折 200  

請撰寫一支程式  
計算客戶消費的結帳金額

# %%
total = 1000
if total >= 2000 :
    total -= 200 


print(total)
# Out:
# 1000

# %%
# 滿 4000 折 400,滿 6000 折 600

total = 8000
discount = 200
if total >= 2000:
    n = total // 2000
    total -= discount * n

print(total)
# Out:
# 7200

# %%
# 滿 4000 折 400,滿 6000 折 600

price = 8000
if price >= 4000 and price <6000 :
    price -= 400

if price >= 6000:
    price -= 600


print(price)
# Out:
# 7400
